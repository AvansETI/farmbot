# %%
from pylabel import importer

import os, zipfile

# %%
path_to_annotations = "datasets/farmbot/cocoFormat/labels/"

#Identify the path to get from the annotations to the images 
path_to_images = "../images/"

yoloclasses = ['beet', 'endive', 'kohlrabi', 'weed']

dataset = importer.ImportYoloV5(path=path_to_annotations, path_to_images=path_to_images, cat_names=yoloclasses,
    img_ext="jpg", name="coco128")

dataset.df.head(5)
# Out:
#     img_folder                              img_filename img_path  img_id  \
# id
# 0   ../images/  02de414b-ed8a-479c-bac8-a46b0441ed8f.jpg      NaN       0
# 1   ../images/  02de414b-ed8a-479c-bac8-a46b0441ed8f.jpg      NaN       0
# 2   ../images/  02de414b-ed8a-479c-bac8-a46b0441ed8f.jpg      NaN       0
# 3   ../images/  02de414b-ed8a-479c-bac8-a46b0441ed8f.jpg      NaN       0
# 4   ../images/  02de414b-ed8a-479c-bac8-a46b0441ed8f.jpg      NaN       0
#
#     img_width  img_height  img_depth ann_segmented  ann_bbox_xmin  \
# id
# 0        1280         720          3           NaN      714.00064
# 1        1280         720          3           NaN      144.99968
# 2        1280         720          3           NaN     1172.00064
# 3        1280         720          3           NaN      716.00064
# 4        1280         720          3           NaN        1.00032
#
#     ann_bbox_ymin  ...  ann_segmentation  ann_iscrowd  ann_pose  \
# id                 ...
# 0       134.99964  ...               NaN          NaN       NaN
# 1         0.99972  ...               NaN          NaN       NaN
# 2         0.99972  ...               NaN          NaN       NaN
# 3       629.00028  ...               NaN          NaN       NaN
# 4         1.00008  ...               NaN          NaN       NaN
#
#     ann_truncated  ann_difficult cat_id cat_name cat_supercategory split  \
# id
# 0             NaN            NaN      3     weed               NaN   NaN
# 1             NaN            NaN      3     weed               NaN   NaN
# 2             NaN            NaN      3     weed               NaN   NaN
# 3             NaN            NaN      3     weed               NaN   NaN
# 4             NaN            NaN      0     beet               NaN   NaN
#
#    annotated
# id
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 25 columns]

# %%
print(f"Number of images: {dataset.analyze.num_images}")
print(f"Number of classes: {dataset.analyze.num_classes}")
print(f"Classes:{dataset.analyze.classes}")
print(f"Class counts:\n{dataset.analyze.class_counts}")
# Out:
# Number of images: 102
# Number of classes: 3
# Classes:['beet', 'kohlrabi', 'weed']
# Class counts:
# weed        155
# beet         90
# kohlrabi     17
# Name: cat_name, dtype: int64

# %%
dataset.export.ExportToCoco(cat_id_index=1)
# Out:
# ['datasets\\farmbot\\cocoFormat\\labels\\coco128.json']
