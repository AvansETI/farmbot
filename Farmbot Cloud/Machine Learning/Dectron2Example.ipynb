# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# TODO: "fix import detectron2"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_54956/198638520.py in <module>
#       2 # Setup detectron2 logger
#       3 import detectron2
# ----> 4 from detectron2.utils.logger import setup_logger
#       5 setup_logger()
#       6
#
# ModuleNotFoundError: No module named 'detectron2.utils'

# %%
# !git clone https://github.com/facebookresearch/detectron2.git
# Out:
# Cloning into 'detectron2'...

# %%
# !python -m pip install -e detectron2
# Out:
# Obtaining file:///C:/Users/jelme/Documents/Avans_stuff/Jaar_4/ML/MLProject/Farmbot%20Cloud/Machine%20Learning/detectron2
# Requirement already satisfied: Pillow>=7.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (8.4.0)
# Requirement already satisfied: matplotlib in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (3.5.1)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (2.0.4)
# Requirement already satisfied: termcolor>=1.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (1.1.0)
# Requirement already satisfied: yacs>=0.1.8 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (0.8.9)
# Requirement already satisfied: cloudpickle in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (2.0.0)
# Requirement already satisfied: tqdm>4.29.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (4.62.3)
# Requirement already satisfied: tensorboard in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (2.7.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (0.1.5.post20211023)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: future in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (0.18.2)
# Requirement already satisfied: pydot in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (1.4.2)
# Requirement already satisfied: omegaconf>=2.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (2.1.1)
# Requirement already satisfied: hydra-core>=1.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (1.1.1)
# Requirement already satisfied: black==21.4b2 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from detectron2==0.6) (21.4b2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from black==21.4b2->detectron2==0.6) (0.4.3)
# Requirement already satisfied: click>=7.1.2 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from black==21.4b2->detectron2==0.6) (8.0.3)
# Requirement already satisfied: regex>=2020.1.8 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from black==21.4b2->detectron2==0.6) (2021.11.10)
# Requirement already satisfied: appdirs in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from black==21.4b2->detectron2==0.6) (1.4.4)
# Requirement already satisfied: pathspec<1,>=0.8.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from black==21.4b2->detectron2==0.6) (0.9.0)
# Requirement already satisfied: toml>=0.10.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from black==21.4b2->detectron2==0.6) (0.10.2)
# Requirement already satisfied: colorama in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from click>=7.1.2->black==21.4b2->detectron2==0.6) (0.4.4)
# Requirement already satisfied: numpy in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.21.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (5.1)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from hydra-core>=1.1->detectron2==0.6) (4.8)
# Requirement already satisfied: portalocker in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from matplotlib->detectron2==0.6) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from matplotlib->detectron2==0.6) (4.28.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from matplotlib->detectron2==0.6) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from matplotlib->detectron2==0.6) (3.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from matplotlib->detectron2==0.6) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from python-dateutil>=2.7->matplotlib->detectron2==0.6) (1.16.0)
# Requirement already satisfied: pywin32>=226 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from portalocker->iopath<0.1.10,>=0.1.7->detectron2==0.6) (302)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (58.0.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (2.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (1.8.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (1.43.0)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (3.19.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (0.37.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2==0.6) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from markdown>=2.6.8->tensorboard->detectron2==0.6) (4.10.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->detectron2==0.6) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jelme\anaconda3\envs\labelenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2==0.6) (3.1.1)
# Installing collected packages: detectron2
#   Running setup.py develop for detectron2
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\jelme\anaconda3\envs\labelenv\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jelme\\Documents\\Avans_stuff\\Jaar_4\\ML\\MLProject\\Farmbot Cloud\\Machine Learning\\detectron2\\setup.py'"'"'; __file__='"'"'C:\\Users\\jelme\\Documents\\Avans_stuff\\Jaar_4\\ML\\MLProject\\Farmbot Cloud\\Machine Learning\\detectron2\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' develop --no-deps
#          cwd: C:\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\
#     Complete output (834 lines):
#     No CUDA runtime is found, using CUDA_HOME='C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.4'
#     running develop
#     running egg_info
#     creating detectron2.egg-info
#     writing detectron2.egg-info\PKG-INFO
#     writing dependency_links to detectron2.egg-info\dependency_links.txt
#     writing requirements to detectron2.egg-info\requires.txt
#     writing top-level names to detectron2.egg-info\top_level.txt
#     writing manifest file 'detectron2.egg-info\SOURCES.txt'
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\utils\cpp_extension.py:381: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#       warnings.warn(msg.format('we could not find ninja.'))
#     reading manifest file 'detectron2.egg-info\SOURCES.txt'
#     adding license file 'LICENSE'
#     writing manifest file 'detectron2.egg-info\SOURCES.txt'
#     running build_ext
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\utils\cpp_extension.py:316: UserWarning: Error checking compiler version for cl: [WinError 2] The system cannot find the file specified
#       warnings.warn(f'Error checking compiler version for {compiler}: {error}')
#     building 'detectron2._C' extension
#     creating build
#     creating build\temp.win-amd64-3.9
#     creating build\temp.win-amd64-3.9\Release
#     creating build\temp.win-amd64-3.9\Release\Users
#     creating build\temp.win-amd64-3.9\Release\Users\jelme
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc\ROIAlignRotated
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc\box_iou_rotated
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc\cocoeval
#     creating build\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc\nms_rotated
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc -IC:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include -IC:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\torch\csrc\api\include -IC:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\TH -IC:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\THC -IC:\Users\jelme\anaconda3\envs\labelenv\include -IC:\Users\jelme\anaconda3\envs\labelenv\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\ATLMFC\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.18362.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.18362.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.18362.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.18362.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.18362.0\cppwinrt /EHsc /TpC:\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp /Fobuild\temp.win-amd64-3.9\Release\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /EHsc -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0
#     ROIAlignRotated_cpu.cpp
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::TensorBase
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=at::TensorBase
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=at::TensorBase
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=at::TensorBase
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<at::TensorBase>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/TensorBase.h(899): note: see reference to class template instantiation 'c10::optional<at::TensorBase>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::TensorBase
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::Tensor
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=at::Tensor
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=at::Tensor
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=at::Tensor
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<at::Tensor>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/TensorBody.h(444): note: see reference to class template instantiation 'c10::optional<at::Tensor>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::Tensor
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::Generator
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=at::Generator
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=at::Generator
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=at::Generator
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<at::Generator>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/TensorBody.h(518): note: see reference to class template instantiation 'c10::optional<at::Generator>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::Generator
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::InlineDeviceGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=c10::impl::InlineDeviceGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=c10::impl::InlineDeviceGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=c10::impl::InlineDeviceGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<c10::impl::InlineDeviceGuard<c10::impl::VirtualGuardImpl>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/core/impl/InlineDeviceGuard.h(427): note: see reference to class template instantiation 'c10::optional<c10::impl::InlineDeviceGuard<c10::impl::VirtualGuardImpl>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/core/DeviceGuard.h(178): note: see reference to class template instantiation 'c10::impl::InlineOptionalDeviceGuard<c10::impl::VirtualGuardImpl>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::InlineDeviceGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::DimVector
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=at::DimVector
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=at::DimVector
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=at::DimVector
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<at::DimVector>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/TensorIterator.h(667): note: see reference to class template instantiation 'c10::optional<at::DimVector>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::DimVector
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::string
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=std::string
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=std::string
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=std::string
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<std::string>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/jit_type_base.h(108): note: see reference to class template instantiation 'c10::optional<std::string>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::string
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::InlineStreamGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=c10::impl::InlineStreamGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=c10::impl::InlineStreamGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=c10::impl::InlineStreamGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<c10::impl::InlineStreamGuard<c10::impl::VirtualGuardImpl>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/core/impl/InlineStreamGuard.h(196): note: see reference to class template instantiation 'c10::optional<c10::impl::InlineStreamGuard<c10::impl::VirtualGuardImpl>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/core/StreamGuard.h(139): note: see reference to class template instantiation 'c10::impl::InlineOptionalStreamGuard<c10::impl::VirtualGuardImpl>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::InlineStreamGuard<c10::impl::VirtualGuardImpl>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::VirtualGuardImpl
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=c10::impl::VirtualGuardImpl
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=c10::impl::VirtualGuardImpl
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=c10::impl::VirtualGuardImpl
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<c10::impl::VirtualGuardImpl>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/core/impl/InlineStreamGuard.h(231): note: see reference to class template instantiation 'c10::optional<T>' being compiled
#             with
#             [
#                 T=c10::impl::VirtualGuardImpl
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/core/StreamGuard.h(162): note: see reference to class template instantiation 'c10::impl::InlineMultiStreamGuard<c10::impl::VirtualGuardImpl>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::VirtualGuardImpl
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<c10::ivalue::Future::WeakStorage,std::allocator<c10::ivalue::Future::WeakStorage>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=std::vector<c10::ivalue::Future::WeakStorage,std::allocator<c10::ivalue::Future::WeakStorage>>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=std::vector<c10::ivalue::Future::WeakStorage,std::allocator<c10::ivalue::Future::WeakStorage>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=std::vector<c10::ivalue::Future::WeakStorage,std::allocator<c10::ivalue::Future::WeakStorage>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<std::vector<c10::ivalue::Future::WeakStorage,std::allocator<c10::ivalue::Future::WeakStorage>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/ivalue_inl.h(374): note: see reference to class template instantiation 'c10::optional<std::vector<c10::ivalue::Future::WeakStorage,std::allocator<c10::ivalue::Future::WeakStorage>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<c10::ivalue::Future::WeakStorage,std::allocator<c10::ivalue::Future::WeakStorage>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<c10::ShapeSymbol,std::allocator<c10::ShapeSymbol>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=std::vector<c10::ShapeSymbol,std::allocator<c10::ShapeSymbol>>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=std::vector<c10::ShapeSymbol,std::allocator<c10::ShapeSymbol>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=std::vector<c10::ShapeSymbol,std::allocator<c10::ShapeSymbol>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<std::vector<c10::ShapeSymbol,std::allocator<c10::ShapeSymbol>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/jit_type.h(426): note: see reference to class template instantiation 'c10::optional<std::vector<c10::ShapeSymbol,std::allocator<c10::ShapeSymbol>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<c10::ShapeSymbol,std::allocator<c10::ShapeSymbol>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<c10::optional<c10::Stride>,std::allocator<c10::optional<c10::Stride>>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=std::vector<c10::optional<c10::Stride>,std::allocator<c10::optional<c10::Stride>>>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=std::vector<c10::optional<c10::Stride>,std::allocator<c10::optional<c10::Stride>>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=std::vector<c10::optional<c10::Stride>,std::allocator<c10::optional<c10::Stride>>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<std::vector<c10::optional<c10::Stride>,std::allocator<c10::optional<c10::Stride>>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/jit_type.h(511): note: see reference to class template instantiation 'c10::optional<std::vector<c10::optional<c10::Stride>,std::allocator<c10::optional<c10::Stride>>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/jit_type.h(750): note: see reference to class template instantiation 'c10::VaryingShape<c10::Stride>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<c10::optional<c10::Stride>,std::allocator<c10::optional<c10::Stride>>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<c10::optional<int64_t>,std::allocator<c10::optional<int64_t>>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=std::vector<c10::optional<int64_t>,std::allocator<c10::optional<int64_t>>>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=std::vector<c10::optional<int64_t>,std::allocator<c10::optional<int64_t>>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=std::vector<c10::optional<int64_t>,std::allocator<c10::optional<int64_t>>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<std::vector<c10::optional<int64_t>,std::allocator<c10::optional<int64_t>>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/jit_type.h(511): note: see reference to class template instantiation 'c10::optional<std::vector<c10::optional<int64_t>,std::allocator<c10::optional<int64_t>>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/jit_type.h(556): note: see reference to class template instantiation 'c10::VaryingShape<int64_t>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<c10::optional<int64_t>,std::allocator<c10::optional<int64_t>>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<int64_t,std::allocator<int64_t>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=std::vector<int64_t,std::allocator<int64_t>>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=std::vector<int64_t,std::allocator<int64_t>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=std::vector<int64_t,std::allocator<int64_t>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<std::vector<int64_t,std::allocator<int64_t>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/jit_type.h(654): note: see reference to class template instantiation 'c10::optional<std::vector<int64_t,std::allocator<int64_t>>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::vector<int64_t,std::allocator<int64_t>>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::QualifiedName
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=c10::QualifiedName
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=c10::QualifiedName
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=c10::QualifiedName
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<c10::QualifiedName>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/jit_type.h(990): note: see reference to class template instantiation 'c10::optional<c10::QualifiedName>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::QualifiedName
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=torch::autograd::ViewInfo
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=torch::autograd::ViewInfo
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=torch::autograd::ViewInfo
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=torch::autograd::ViewInfo
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<torch::autograd::ViewInfo>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\torch/csrc/autograd/variable.h(525): note: see reference to class template instantiation 'c10::optional<torch::autograd::ViewInfo>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
# ...
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\torch/csrc/jit/ir/constants.h(29): note: see reference to class template instantiation 'c10::optional<torch::jit::ScopePtr>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=torch::jit::ScopePtr
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::AnnotatedSchema
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=c10::impl::AnnotatedSchema
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=c10::impl::AnnotatedSchema
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=c10::impl::AnnotatedSchema
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<c10::impl::AnnotatedSchema>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/dispatch/OperatorEntry.h(193): note: see reference to class template instantiation 'c10::optional<c10::impl::AnnotatedSchema>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::AnnotatedSchema
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::OperatorEntry::CppSignatureWithDebug
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=c10::impl::OperatorEntry::CppSignatureWithDebug
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=c10::impl::OperatorEntry::CppSignatureWithDebug
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=c10::impl::OperatorEntry::CppSignatureWithDebug
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<c10::impl::OperatorEntry::CppSignatureWithDebug>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/dispatch/OperatorEntry.h(252): note: see reference to class template instantiation 'c10::optional<c10::impl::OperatorEntry::CppSignatureWithDebug>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::impl::OperatorEntry::CppSignatureWithDebug
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::OperatorName
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=c10::OperatorName
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=c10::OperatorName
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=c10::OperatorName
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<c10::OperatorName>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/record_function.h(320): note: see reference to class template instantiation 'c10::optional<c10::OperatorName>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::OperatorName
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::either<c10::OperatorName,c10::FunctionSchema>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=c10::either<c10::OperatorName,c10::FunctionSchema>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=c10::either<c10::OperatorName,c10::FunctionSchema>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=c10::either<c10::OperatorName,c10::FunctionSchema>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<c10::either<c10::OperatorName,c10::FunctionSchema>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\ATen/core/op_registration/op_registration.h(434): note: see reference to class template instantiation 'c10::optional<c10::either<c10::OperatorName,c10::FunctionSchema>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=c10::either<c10::OperatorName,c10::FunctionSchema>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::ThreadLocalState
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=at::ThreadLocalState
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=at::ThreadLocalState
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=at::ThreadLocalState
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<at::ThreadLocalState>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\torch/csrc/jit/runtime/interpreter.h(144): note: see reference to class template instantiation 'c10::optional<at::ThreadLocalState>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=at::ThreadLocalState
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::shared_ptr<torch::jit::Graph>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=std::shared_ptr<torch::jit::Graph>
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=std::shared_ptr<torch::jit::Graph>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=std::shared_ptr<torch::jit::Graph>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<std::shared_ptr<torch::jit::Graph>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\torch/csrc/jit/api/function_impl.h(125): note: see reference to class template instantiation 'c10::optional<std::shared_ptr<torch::jit::Graph>>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=std::shared_ptr<torch::jit::Graph>
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(184): warning C4624: 'c10::constexpr_storage_t<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=torch::jit::Method
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(383): note: see reference to class template instantiation 'c10::constexpr_storage_t<T>' being compiled
#             with
#             [
#                 T=torch::jit::Method
#             ]
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.25.28610\include\type_traits(640): note: see reference to class template instantiation 'c10::trivially_copyable_optimization_optional_base<T>' being compiled
#             with
#             [
#                 T=torch::jit::Method
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to class template instantiation 'std::is_copy_constructible<c10::trivially_copyable_optimization_optional_base<T>>' being compiled
#             with
#             [
#                 T=torch::jit::Method
#             ]
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(526): note: see reference to alias template instantiation 'c10::OptionalBase<torch::jit::Method>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\torch/csrc/jit/api/object.h(43): note: see reference to class template instantiation 'c10::optional<torch::jit::Method>' being compiled
#     C:\Users\jelme\anaconda3\envs\labelenv\lib\site-packages\torch\include\c10/util/Optional.h(418): warning C4624: 'c10::trivially_copyable_optimization_optional_base<T>': destructor was implicitly defined as deleted
#             with
#             [
#                 T=torch::jit::Method
#             ]
#     C:\Users\jelme\Documents\Avans_stuff\Jaar_4\ML\MLProject\Farmbot Cloud\Machine Learning\detectron2\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp : fatal error C1083: Cannot open compiler generated file: '': Invalid argument
#     error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\Community\\VC\\Tools\\MSVC\\14.25.28610\\bin\\HostX86\\x64\\cl.exe' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\jelme\anaconda3\envs\labelenv\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jelme\\Documents\\Avans_stuff\\Jaar_4\\ML\\MLProject\\Farmbot Cloud\\Machine Learning\\detectron2\\setup.py'"'"'; __file__='"'"'C:\\Users\\jelme\\Documents\\Avans_stuff\\Jaar_4\\ML\\MLProject\\Farmbot Cloud\\Machine Learning\\detectron2\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' develop --no-deps Check the logs for full command output.
